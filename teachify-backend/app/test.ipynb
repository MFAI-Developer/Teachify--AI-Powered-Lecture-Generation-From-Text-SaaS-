# %%
# %pip install moviepy
# Out:
# Requirement already satisfied: moviepy in /Users/fawadkhan/PycharmProjects/Teachify/teachify-backend/.venv/lib/python3.9/site-packages (2.2.1)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/fawadkhan/PycharmProjects/Teachify/teachify-backend/.venv/lib/python3.9/site-packages (from moviepy) (5.2.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/fawadkhan/PycharmProjects/Teachify/teachify-backend/.venv/lib/python3.9/site-packages (from moviepy) (2.37.2)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /Users/fawadkhan/PycharmProjects/Teachify/teachify-backend/.venv/lib/python3.9/site-packages (from moviepy) (0.6.0)
# Requirement already satisfied: numpy>=1.25.0 in /Users/fawadkhan/PycharmProjects/Teachify/teachify-backend/.venv/lib/python3.9/site-packages (from moviepy) (2.0.2)
# Requirement already satisfied: proglog<=1.0.0 in /Users/fawadkhan/PycharmProjects/Teachify/teachify-backend/.venv/lib/python3.9/site-packages (from moviepy) (0.1.12)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/fawadkhan/PycharmProjects/Teachify/teachify-backend/.venv/lib/python3.9/site-packages (from moviepy) (1.2.1)
# Requirement already satisfied: pillow<12.0,>=9.2.0 in /Users/fawadkhan/PycharmProjects/Teachify/teachify-backend/.venv/lib/python3.9/site-packages (from moviepy) (11.3.0)
# Requirement already satisfied: tqdm in /Users/fawadkhan/PycharmProjects/Teachify/teachify-backend/.venv/lib/python3.9/site-packages (from proglog<=1.0.0->moviepy) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# test_gemini_key.py
from google import genai

# put your key here
API_KEY = "AIzaSyB6nok50xX8bLYr6HttZnhqqJMC7CgTWls"

try:
    client = genai.Client(api_key=API_KEY)
    print("✅ Gemini client initialized successfully!")

    # simple test request
    response = client.models.generate_content(
        model="gemini-2.5-flash",  # lightweight and fast model
        contents="Write a short motivational quote about learning."
    )

    print("\n✅ Gemini API Response:")
    print(response.text)

except Exception as e:
    print("\n❌ Gemini test failed:")
    print(e)
# Out:
# ✅ Gemini client initialized successfully!
#
# ✅ Gemini API Response:
# Here are a few options:
#
# *   "Learn daily, grow endlessly."
# *   "Learning unlocks a world of possibilities."
# *   "Every lesson learned builds a better you."
# *   "Curiosity fuels knowledge; knowledge fuels growth."
# *   "Invest in learning; it pays lifelong dividends."
